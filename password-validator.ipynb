# %%
def check_password_strength(password):
    length= len(password) >= 8
    upper = any(char.isupper() for char in password)
    lower = any(char.islower() for char in password)
    digit = any(char.isdigit() for char in password)
    special = any(not char.isalnum() for char in password)
    score = sum([length, upper, lower, digit, special])
    if score == 5:
        print("  ---Strong Password---")
    elif score >= 3:
        print("---Medium Password--- ")
    else:
        print("---Weak Password---")
    print("\n Details:")
    print(" At least 8 characters" if length else " X--Less than 8 characters")
    print(" Contains uppercase letter" if upper else " X--No uppercase letter")
    print(" Contains Lowercase letter" if lower else " X--No lowercase letter")
    print(" Contain digits" if digit else " X--no digit ")
    print(" Contains special character" if special else " X--No special characters")
password = input("Enter your password: ")
check_password_strength(password)
# Out:
# Enter your password:  Nikbhi20
# ---Medium Password---
#
#  Details:
#  At least 8 characters
#  Contains uppercase letter
#  Contains Lowercase letter
#  Contain digits
#  X--No special characters
